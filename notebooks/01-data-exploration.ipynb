# %%
import pandas as pd
from pathlib import Path

csv_path = Path.cwd() / ".." / "data" / "RecipeNLG_dataset.csv"

try:
    df = pd.read_csv(csv_path, header=None, nrows=5)

    print("--- Имена колонок, определенные pandas ---")
    print(df.columns)

    print("\n--- Первые 5 строк файла ---")
    display(df)

except FileNotFoundError:
    print(f"Файл не найден по пути: {csv_path}")
    print("Пожалуйста, убедитесь, что файл `RecipeNLG_dataset.csv` находится в папке `data`.")
# Out:
# --- Имена колонок, определенные pandas ---
# Index([0, 1, 2, 3, 4, 5, 6], dtype='int64')
#
# --- Первые 5 строк файла ---
#      0                      1  \
# 0  NaN                  title
# 1  0.0    No-Bake Nut Cookies
# 2  1.0  Jewell Ball'S Chicken
# 3  2.0            Creamy Corn
# 4  3.0          Chicken Funny
#
#                                                    2  \
# 0                                        ingredients
# 1  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 2  ["1 small jar chipped beef, cut up", "4 boned ...
# 3  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 4  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
#
#                                                    3  \
# 0                                         directions
# 1  ["In a heavy 2-quart saucepan, mix brown sugar...
# 2  ["Place chipped beef on bottom of baking dish....
# 3  ["In a slow cooker, combine all ingredients. C...
# 4  ["Boil and debone chicken.", "Put bite size pi...
#
# ...
